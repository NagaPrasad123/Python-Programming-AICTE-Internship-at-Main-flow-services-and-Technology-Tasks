# %%
from tkinter import *
from tkinter.scrolledtext import ScrolledText
from tkinter import messagebox, filedialog
import random
from datetime import datetime

# Function to calculate total bills
def total_bills():
    # Prices of drinks and food items
    lassi_price = 50
    coffee_price = 20
    tea_price = 18
    juice_price = 38
    shakes_price = 58
    milk_price = 20
    shikanji_price = 15
    redbull_price = 156

    roti_price = 5
    dal_makhni_price = 120
    mutter_paneer_price = 150
    paratha_price = 46
    mix_veg_price = 70
    omelette_price = 20
    veg_biryani_price = 120
    rice_price = 50

    # Retrieving the quantities from the entry fields
    lassi_q = int(lassi_qty.get()) if lassi_var.get() == 1 else 0
    coffee_q = int(coffee_qty.get()) if coffee_var.get() == 1 else 0
    tea_q = int(tea_qty.get()) if tea_var.get() == 1 else 0
    juice_q = int(juice_qty.get()) if juice_var.get() == 1 else 0
    shakes_q = int(shakes_qty.get()) if shakes_var.get() == 1 else 0
    milk_q = int(milk_qty.get()) if milk_var.get() == 1 else 0
    shikanji_q = int(shikanji_qty.get()) if shikanji_var.get() == 1 else 0
    redbull_q = int(redbull_qty.get()) if redbull_var.get() == 1 else 0

    roti_q = int(roti_qty.get()) if roti_var.get() == 1 else 0
    dal_makhni_q = int(dal_makhni_qty.get()) if dal_makhni_var.get() == 1 else 0
    mutter_paneer_q = int(mutter_paneer_qty.get()) if mutter_paneer_var.get() == 1 else 0
    paratha_q = int(paratha_qty.get()) if paratha_var.get() == 1 else 0
    mix_veg_q = int(mix_veg_qty.get()) if mix_veg_var.get() == 1 else 0
    omelette_q = int(omelette_qty.get()) if omelette_var.get() == 1 else 0
    veg_biryani_q = int(veg_biryani_qty.get()) if veg_biryani_var.get() == 1 else 0
    rice_q = int(rice_qty.get()) if rice_var.get() == 1 else 0

    # Calculating total prices
    total_lassi_price = lassi_price * lassi_q
    total_coffee_price = coffee_price * coffee_q
    total_tea_price = tea_price * tea_q
    total_juice_price = juice_price * juice_q
    total_shakes_price = shakes_price * shakes_q
    total_milk_price = milk_price * milk_q
    total_shikanji_price = shikanji_price * shikanji_q
    total_redbull_price = redbull_price * redbull_q

    total_roti_price = roti_price * roti_q
    total_dal_makhni_price = dal_makhni_price * dal_makhni_q
    total_mutter_paneer_price = mutter_paneer_price * mutter_paneer_q
    total_paratha_price = paratha_price * paratha_q
    total_mix_veg_price = mix_veg_price * mix_veg_q
    total_omelette_price = omelette_price * omelette_q
    total_veg_biryani_price = veg_biryani_price * veg_biryani_q
    total_rice_price = rice_price * rice_q

    # Total cost calculations
    total_drinks_cost = (total_lassi_price + total_coffee_price + total_tea_price + total_juice_price +
                         total_shakes_price + total_milk_price + total_shikanji_price + total_redbull_price)

    total_foods_cost = (total_roti_price + total_dal_makhni_price + total_mutter_paneer_price +
                        total_paratha_price + total_mix_veg_price + total_omelette_price +
                        total_veg_biryani_price + total_rice_price)

    # Display the total cost
    drinks_cost.delete(0, "end")
    drinks_cost.insert("end", total_drinks_cost)

    foods_cost.delete(0, "end")
    foods_cost.insert("end", total_foods_cost)

# GUI Setup (This should be expanded with buttons, entry fields, etc.)
root = Tk()
root.title("Bill Calculator")
root.geometry("500x500")

# Other necessary GUI elements like buttons and input fields go here

root.mainloop()
